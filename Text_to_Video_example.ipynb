# %% [markdown]
# <a href="https://colab.research.google.com/github/SamurAIGPT/Text-To-Video-AI/blob/main/Text_to_Video_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Steps for generating video from text
#
# 1. Use openai to generate a video script from a topic
# 2. Use edgetts to pick a voice and create a audio based on the above generated script
# 3. Use whisper and get timed captions for the above audio
# 4. Now generate visual keywords for the video script using openai api
# 5. Fetch videos based on the above visual keywords using pexels api
# 6. Stich together the videos, audio and captions using Moviepy

# %% [markdown]
# ### Install python 3.11

# %%
# !sudo apt-get update -y
# !sudo apt-get install -y python3.11
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.11 1
# !sudo update-alternatives --config python3
# !sudo apt-get install -y python3.11-distutils
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3.11 get-pip.py

# %%
# !git clone https://github.com/SamurAIGPT/Text-To-Video-AI

# %%
# %cd Text-To-Video-AI

# %% [markdown]
# ### Install dependencies

# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached aiohttp-3.9.5-cp312-cp312-win_amd64.whl.metadata (7.7 kB)
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached dtw_python-1.5.1-cp312-cp312-win_amd64.whl.metadata (48 kB)
# ...
#   Using cached edge_tts-6.1.12-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached moviepy-1.0.3-py3-none-any.whl
# ...
#   Using cached numba-0.59.1-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# ...
#   Using cached openai-1.31.1-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached openai_whisper-20231117-py3-none-any.whl
# ...
#   Using cached proglog-0.1.10-py3-none-any.whl.metadata (639 bytes)
# ...
#   Using cached pydantic-2.7.3-py3-none-any.whl.metadata (108 kB)
# ...
#   Using cached tiktoken-0.7.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# ...

# %%
# !python --version
# Out:
# Python 3.11.11

# %% [markdown]
# ### Setup api keys

# %%
import os

#for text generation, use openai or groq. groq model used: "llama3-70b-8192"
#note: use just one
#os.environ["OPENAI_KEY"]="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"
os.environ['GROQ_API_KEY'] = "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"

os.environ["PEXELS_KEY"]="V7GpqImF6WygFzs7uliDEiiKWYRHfPM9k3kwG1VtoA3W3mGBwDnPEyRm"

# %% [markdown]
# ### Modify permissions for Imagemagick (workaround in colab)

# %%
# !apt install imagemagick &> /dev/null
# !sed -i '/<policy domain="path" rights="none" pattern="@\*"/d' /etc/ImageMagick-6/policy.xml
# Out:
# The syntax of the command is incorrect.
# The system cannot find the file specified.

# %%
# !pip install numpy<2.0,>=1.20 --force-reinstall
# !pip install scipy<1.14.0,>=1.7.0 --force-reinstall
# !pip install fsspec==2024.6.1 --force-reinstall
# !pip install --upgrade --force-reinstall whisper_timestamped

# %%
# !pip uninstall whisper-timestamped openai-whisper -y
# !pip install whisper-timestamped openai-whisper

# %%
# !pip check

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- ------------------
# aiobotocore                       2.12.3
# aiohappyeyeballs                  2.4.0
# aiohttp                           3.10.5
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# altair                            5.0.1
# anaconda-anon-usage               0.4.4
# anaconda-catalogs                 0.2.0
# anaconda-client                   1.12.3
# anaconda-cloud-auth               0.5.1
# anaconda-navigator                2.6.3
# anaconda-project                  0.11.1
# annotated-types                   0.6.0
# anyio                             4.2.0
# appdirs                           1.4.4
# archspec                          0.2.3
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.3
# astroid                           2.14.2
# ...

# %%
import os
os.environ["FFMPEG_BINARY"] = "ffmpeg"

# %%
import os

# Replace with the actual path to your ffmpeg.exe
os.environ["PATH"] += os.pathsep + r"D:\Users anand data\Downloads\ffmpeg-2024-12-23-git-6c9218d748-essentials_build\ffmpeg-2024-12-23-git-6c9218d748-essentials_build\bin"

import subprocess
subprocess.run(["ffmpeg", "-version"], check=True)
# Out:
# CompletedProcess(args=['ffmpeg', '-version'], returncode=0)

# %%
import subprocess

try:
    result = subprocess.run(["ffmpeg", "-version"], capture_output=True, text=True, check=True)
    print("FFmpeg is working:", result.stdout)
except FileNotFoundError:
    print("FFmpeg not found. Check PATH or installation.")
except Exception as e:
    print("Error:", e)
# Out:
# FFmpeg is working: ffmpeg version 2024-12-23-git-6c9218d748-essentials_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
# built with gcc 14.2.0 (Rev1, Built by MSYS2 project)
# ...

# %%
# !magick -version
# Out:
# Version: ImageMagick 7.1.1-43 Q16-HDRI x64 a2d96f4:20241222 https://imagemagick.org
# Copyright: (C) 1999 ImageMagick Studio LLC
# License: https://imagemagick.org/script/license.php
# Features: Channel-masks(64-bit) Cipher DPC HDRI Modules OpenCL OpenMP(2.0)
# Delegates (built-in): bzlib cairo flif freetype gslib heic jng jp2 jpeg jxl lcms lqr lzma openexr pangocairo png ps raqm raw rsvg tiff webp xml zip zlib
# Compiler: Visual Studio 2022 (194234435)

# %%
from moviepy.config import change_settings

change_settings({"IMAGEMAGICK_BINARY": "C:\\Program Files\\ImageMagick-7.1.1-Q16-HDRI\\magick.exe"})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from moviepy.config import change_settings
#       3 change_settings({"IMAGEMAGICK_BINARY": "C:\\Program Files\\ImageMagick-7.1.1-Q16-HDRI\\magick.exe"})
#
# ModuleNotFoundError: No module named 'moviepy'

# %% [markdown]
# ### Generate video from topic

# %%
# !python app.py "flower"
# Out:
# Content before parsing: '{"script": "Did you know?\\n1. Sunflowers aren\\"t just one flower, they\\"re actually a cluster of hundreds of tiny flowers.\\n2. The largest flower in the world is the Rafflesia arnoldii, which can grow up to 3 feet in diameter.\\n3. Broccoli, cauliflower, and kale are all technically flowers.\\n4. The venus flytrap is a carnivorous flower that eats insects.\\n5. Roses are not just red; they come in over 150 species and thousands of hybrid varieties with various colors and shapes."}'
# script: Did you know?
# 1. Sunflowers aren"t just one flower, they"re actually a cluster of hundreds of tiny flowers.
# 2. The largest flower in the world is the Rafflesia arnoldii, which can grow up to 3 feet in diameter.
# 3. Broccoli, cauliflower, and kale are all technically flowers.
# ...
# 100%|##########| 3105/3105 [00:12<00:00, 242.40frames/s]
#
# ...
# chunk:  99%|#########8| 678/685 [00:03<00:00, 233.02it/s, now=None]
#
#
# ...

# %% [markdown]
# ### Display video

# %%
import whisper_timestamped as whisper
from whisper.audio import load_audio

audio_path = "C:\\Users\\anand\\Text-To-Video-AI-main\\Text-To-Video-AI-main\\audio_tts.wav"
try:
    audio = load_audio(audio_path)
    print("Audio loaded successfully!")
except Exception as e:
    print(f"Error loading audio: {e}")
# Out:
# Audio loaded successfully!

# %%
from IPython.display import HTML
from base64 import b64encode

# Path to the video file
video_path = 'rendered_video.mp4'

# Function to display video
def display_video(video_path, width=640, height=480):
    # Load video
    video_file = open(video_path, "rb").read()
    video_url = "data:video/mp4;base64," + b64encode(video_file).decode()
    return HTML(f"""
    <video width={width} height={height} controls>
        <source src="{video_url}" type="video/mp4">
    </video>
    """)

# Display video
display_video(video_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 19
#      12     return HTML(f"""
#      13     <video width={width} height={height} controls>
#      14         <source src="{video_url}" type="video/mp4">
#      15     </video>
#      16     """)
#      18 # Display video
# ---> 19 display_video(video_path)
#
# Cell In[27], line 10, in display_video(video_path, width, height)
#       8 def display_video(video_path, width=640, height=480):
#       9     # Load video
# ---> 10     video_file = open(video_path, "rb").read()
#      11     video_url = "data:video/mp4;base64," + b64encode(video_file).decode()
#      12     return HTML(f"""
#      13     <video width={width} height={height} controls>
#      14         <source src="{video_url}" type="video/mp4">
#      15     </video>
#      16     """)
#
# ...
